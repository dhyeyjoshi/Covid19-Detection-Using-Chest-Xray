# %%
import pandas as pd
import os 
import shutil

# %%
#Create data for the positive samples(Git-hub)
FILE_PATH ="chestxray/metadata.csv"
IMAGES_PATH = "chestxray/images"

# %%
df = pd.read_csv(FILE_PATH)
print(df.shape)
# Out:
# (755, 29)

# %%
df.head()
# Out:
#   patientid  offset sex   age   finding RT_PCR_positive survival intubated  \
# 0         2     0.0   M  65.0  COVID-19               Y        Y         N
# 1         2     3.0   M  65.0  COVID-19               Y        Y         N
# 2         2     5.0   M  65.0  COVID-19               Y        Y         N
# 3         2     6.0   M  65.0  COVID-19               Y        Y         N
# 4         4     0.0   F  52.0  COVID-19               Y      NaN         N
#
#   intubation_present went_icu  ... modality              date  \
# 0                  N        N  ...    X-ray  January 22, 2020
# 1                  N        N  ...    X-ray  January 25, 2020
# 2                  N        N  ...    X-ray  January 27, 2020
# 3                  N        N  ...    X-ray  January 28, 2020
# 4                  N        N  ...    X-ray  January 25, 2020
#
#                                             location  folder  \
# 0        Cho Ray Hospital, Ho Chi Minh City, Vietnam  images
# ...

# %%
TARGET_DIR= "Dataset/Covid"

if not os.path.exists(TARGET_DIR) :
    os.mkdir(TARGET_DIR)
    print("Covid folder is created")
# Out:
# Covid folder is created

# %%
cnt = 0

for (i,row) in df.iterrows():
    if row["finding"]=="COVID-19" and row ["view"]=="PA" :
        filename=row["filename"]
        image_path = os.path.join(IMAGES_PATH,filename)
        image_copy_path = os.path.join(TARGET_DIR,filename)
        shutil.copy2(image_path,image_copy_path)
       # print("Moving image" , cnt)
        cnt += 1

# %%
#Sampling of Images from kaagle 

import random 
KAAGLE_FILE_NAME="chest_xray_kaagle/train/NORMAL"
TARGET_NORMAL_DIR="Dataset/Normal"

# %%
image_names = os.listdir(KAAGLE_FILE_NAME)

# %%
image_names
# Out:
# ['IM-0115-0001.jpeg',
#  'IM-0117-0001.jpeg',
#  'IM-0119-0001.jpeg',
#  'IM-0122-0001.jpeg',
#  'IM-0125-0001.jpeg',
#  'IM-0127-0001.jpeg',
#  'IM-0128-0001.jpeg',
#  'IM-0129-0001.jpeg',
#  'IM-0131-0001.jpeg',
#  'IM-0133-0001.jpeg',
#  'IM-0135-0001.jpeg',
#  'IM-0137-0001.jpeg',
#  'IM-0140-0001.jpeg',
#  'IM-0141-0001.jpeg',
#  'IM-0143-0001.jpeg',
#  'IM-0145-0001.jpeg',
#  'IM-0147-0001.jpeg',
#  'IM-0149-0001.jpeg',
#  'IM-0151-0001.jpeg',
#  'IM-0152-0001.jpeg',
#  'IM-0154-0001.jpeg',
#  'IM-0156-0001.jpeg',
#  'IM-0158-0001.jpeg',
#  'IM-0160-0001.jpeg',
#  'IM-0162-0001.jpeg',
#  'IM-0164-0001.jpeg',
#  'IM-0166-0001.jpeg',
#  'IM-0168-0001.jpeg',
#  'IM-0170-0001.jpeg',
#  'IM-0172-0001.jpeg',
#  'IM-0176-0001.jpeg',
#  'IM-0177-0001.jpeg',
#  'IM-0178-0001.jpeg',
#  'IM-0180-0001.jpeg',
#  'IM-0182-0001.jpeg',
#  'IM-0183-0001.jpeg',
#  'IM-0185-0001.jpeg',
#  'IM-0187-0001.jpeg',
#  'IM-0189-0001.jpeg',
#  'IM-0191-0001.jpeg',
#  'IM-0193-0001.jpeg',
# ...

# %%
random.shuffle(image_names)

# %%
for i in range(142) :
    
    image_name=image_names[i]
    image_path = os.path.join(KAAGLE_FILE_NAME,image_name)
    target_path = os.path.join(TARGET_NORMAL_DIR,image_name)
    shutil.copy2(image_path,target_path)
    print("Copying image",i)
# Out:
# Copying image 0
# Copying image 1
# Copying image 2
# Copying image 3
# Copying image 4
# Copying image 5
# Copying image 6
# Copying image 7
# Copying image 8
# Copying image 9
# Copying image 10
# Copying image 11
# Copying image 12
# Copying image 13
# Copying image 14
# Copying image 15
# Copying image 16
# Copying image 17
# Copying image 18
# Copying image 19
# Copying image 20
# Copying image 21
# Copying image 22
# Copying image 23
# Copying image 24
# Copying image 25
# Copying image 26
# Copying image 27
# Copying image 28
# Copying image 29
# Copying image 30
# Copying image 31
# Copying image 32
# Copying image 33
# Copying image 34
# Copying image 35
# Copying image 36
# Copying image 37
# Copying image 38
# Copying image 39
# Copying image 40
# Copying image 41
# Copying image 42
# Copying image 43
# Copying image 44
# Copying image 45
# Copying image 46
# Copying image 47
# Copying image 48
# Copying image 49
# Copying image 50
# Copying image 51
# Copying image 52
# ...
